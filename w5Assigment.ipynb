# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Importing data from csv file

# %%
dfa = pd.read_csv('C:/Users/d/Desktop/uw/hw/w5/assig/airports.csv')
dfa.head()
# Out:
#    faa                           name        lat        lon   alt   tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044 -5.0   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264 -6.0   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801 -6.0   A
# 3  06N                Randall Airport  41.431912 -74.391561   523 -5.0   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11 -5.0   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
dfws = pd.read_csv('C:/Users/d/Desktop/uw/hw/w5/assig/weather.csv')
dfws.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib             time_hour
# 0  11.918651     0.0    1013.9   10.0  2013-01-01T00:00:00Z
# 1  15.891535     0.0    1013.0   10.0  2013-01-01T01:00:00Z
# 2  14.567241     0.0    1012.6   10.0  2013-01-01T02:00:00Z
# 3  15.891535     0.0    1012.7   10.0  2013-01-01T03:00:00Z
# 4  17.215830     0.0    1012.8   10.0  2013-01-01T04:00:00Z

# %% [markdown]
# Filtering only 12th of February 2013

# %%
dfw = dfws[dfws['time_hour'].str.contains("2013-02-12")]
dfw.head()
# Out:
#      origin  year  month  day  hour   temp   dewp   humid  wind_dir  \
# 1007    EWR  2013      2   12     0  42.98  42.98  100.00       0.0
# 1008    EWR  2013      2   12     1  42.08  42.08  100.00     300.0
# 1009    EWR  2013      2   12     2  42.80  42.80  100.00     310.0
# 1010    EWR  2013      2   12     3  42.80  42.80  100.00     280.0
# 1011    EWR  2013      2   12     4  44.60  42.80   93.35     290.0
#
#       wind_speed  wind_gust  precip  pressure  visib             time_hour
# 1007     0.00000   0.000000     0.0    1004.7    0.5  2013-02-12T00:00:00Z
# 1008     3.45234   3.972884     0.0    1004.7    0.5  2013-02-12T01:00:00Z
# 1009     8.05546   9.270062     0.0       NaN    1.5  2013-02-12T02:00:00Z
# 1010     5.75390   6.621473     0.0       NaN    3.0  2013-02-12T03:00:00Z
# 1011     8.05546   9.270062     0.0       NaN   10.0  2013-02-12T04:00:00Z

# %% [markdown]
# Question: What is the northernmost airport in the United States? Answer: With the biggest Latitude

# %%
northernmost = dfa.sort_values('lat', ascending=False)

# %%
northernmost.head()
# Out:
#      faa                                        name        lat         lon  \
# 417  EEN                     Dillant Hopkins Airport  72.270833   42.898333
# 230  BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 110  AIN                          Wainwright Airport  70.638056 -159.994722
# 708  K03                               Wainwright As  70.613378 -159.860350
# 152  ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
#
#      alt   tz dst              tzone
# 417  149 -5.0   A                 \N
# 230   44 -9.0   A  America/Anchorage
# 110   41 -9.0   A  America/Anchorage
# 708   35 -9.0   A  America/Anchorage
# 152   96 -9.0   A  America/Anchorage

# %% [markdown]
# Question: What is the easternmost airport in the United States? Answer: With the smallest Longitude

# %%
easternmost = dfa.sort_values('lon', ascending=False)

# %%
easternmost.head()
# Out:
#       faa                           name        lat         lon   alt   tz  \
# 1290  SYA                   Eareckson As  52.712275  174.113620    98 -9.0
# 942   MYF               Montgomery Field  32.475900  117.759000    17  8.0
# 396   DVT  Deer Valley Municipal Airport  33.411700  112.457000  1478  8.0
# 417   EEN        Dillant Hopkins Airport  72.270833   42.898333   149 -5.0
# 444   EPM     Eastport Municipal Airport  44.910111  -67.012694    45 -5.0
#
#      dst              tzone
# 1290   A  America/Anchorage
# 942    A     Asia/Chongqing
# 396    A     Asia/Chongqing
# 417    A                 \N
# 444    A   America/New_York

# %% [markdown]
# Getting only NY airports and renaming column so it would be possible to merge two dataframes

# %%
nyairportsstage = dfa.loc[dfa['tzone'] == 'America/New_York']
nyairports = nyairportsstage.rename(columns={'faa':'origin'})
nyairports.head()
# Out:
#   origin                            name        lat        lon   alt   tz dst  \
# 0    04G               Lansdowne Airport  41.130472 -80.619583  1044 -5.0   A
# 3    06N                 Randall Airport  41.431912 -74.391561   523 -5.0   A
# 4    09J           Jekyll Island Airport  31.074472 -81.427778    11 -5.0   A
# 5    0A9  Elizabethton Municipal Airport  36.371222 -82.173417  1593 -5.0   A
# 6    0G6         Williams County Airport  41.467306 -84.506778   730 -5.0   A
#
#               tzone
# 0  America/New_York
# 3  America/New_York
# 4  America/New_York
# 5  America/New_York
# 6  America/New_York

# %%
merging two dataframes to get only NY airpors on one day

# %%
me =  pd.merge(dfw,nyairports)

# %%
me.sort_values('wind_speed', ascending=False).head()
# Out:
#    origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 8     EWR  2013      2   12     8  39.02  26.96  61.63     260.0  1048.36058
# 55    LGA  2013      2   12     7  42.98  26.06  50.94     290.0    23.01560
# 17    EWR  2013      2   12    17  44.06  26.06  48.87     270.0    21.86482
# 66    LGA  2013      2   12    18  44.06  23.00  43.02     300.0    21.86482
# 37    JFK  2013      2   12    13  42.08  24.08  48.56     280.0    20.71404
#
#           ...         pressure  visib             time_hour  \
# 8         ...           1008.3   10.0  2013-02-12T08:00:00Z
# 55        ...           1007.1   10.0  2013-02-12T07:00:00Z
# 17        ...           1012.5   10.0  2013-02-12T17:00:00Z
# 66        ...           1011.7   10.0  2013-02-12T18:00:00Z
# 37        ...           1011.6   10.0  2013-02-12T13:00:00Z
#
#                    name        lat        lon  alt   tz  dst             tzone
# ...

# %% [markdown]
# Answers:
# 1-Northemost airport by the data is Dillant Hopkins Airport which is not true, this airport location is false because it is different than on google maps. So next would be Wiley Post Will Rogers Mem. Proof: https://en.wikipedia.org/wiki/Wiley_Post%E2%80%93Will_Rogers_Memorial_Airport
# 2-Eastmost airport Eareckson As
# 3-The windies weather was  at Newark Liberty Intl airport
